# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch.distributions import Normal, Categorical, kl_divergence
from torch.nn.utils import clip_grad_value_
from itertools import cycle
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.manifold import TSNE
from torch.utils.data import DataLoader, Subset, TensorDataset
import random

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super().__init__()
        # Encoder
        self.enc_fc1 = nn.Linear(input_dim, hidden_dim)
        self.enc_mu = nn.Linear(hidden_dim, latent_dim)
        self.enc_logvar = nn.Linear(hidden_dim, latent_dim)
        # Decoder
        self.dec_fc1 = nn.Linear(latent_dim, hidden_dim)
        self.dec_fc2 = nn.Linear(hidden_dim, input_dim)

    def encode(self, x):
        h = F.relu(self.enc_fc1(x))
        mu, logvar = self.enc_mu(h), self.enc_logvar(h)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        h = F.relu(self.dec_fc1(z))
        return torch.sigmoid(self.dec_fc2(h))

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        x_recon = self.decode(z)
        return x_recon, mu, logvar

# %%
# Hyperparameters
input_dim = 32 * 32 * 3 # CIFAR10 images
hidden_dim = 256
vae_latent_dim = 50
latent_dim = 50
num_classes = 10
learning_rate = 1e-3
batch_size = 256
num_epochs = 100
vae_num_epochs = 100

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.view(-1))
])

train_dataset = datasets.CIFAR10(root='./data', train=True, transform=transform, download=True)

test_dataset = datasets.CIFAR10(root='./data', train=False, transform=transform, download=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:01<00:00, 101MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

m1 = VAE(input_dim, hidden_dim, vae_latent_dim).to(device)
optimizer_m1 = optim.Adam(m1.parameters(), lr=learning_rate)

train_loader_all = DataLoader(train_dataset, batch_size=256, shuffle=True)

for epoch in range(vae_num_epochs):
    m1.train()
    total_loss = 0
    for x, _ in train_loader_all:
        x = x.to(device)
        x_recon, mu, logvar = m1(x)

        #recon_loss = nn.functional.binary_cross_entropy(x_recon, x, reduction='sum')
        recon_loss = F.mse_loss(x_recon, x, reduction='sum')
        kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
        loss = recon_loss + kl_loss

        optimizer_m1.zero_grad()
        loss.backward()
        optimizer_m1.step()
        total_loss += loss.item()
    print(f"M1 Epoch {epoch+1}, Loss: {total_loss/len(train_loader_all.dataset):.4f}")
# Out:
# Using device: cuda
# M1 Epoch 1, Loss: 149.2528
# M1 Epoch 2, Loss: 114.7747
# M1 Epoch 3, Loss: 101.9338
# M1 Epoch 4, Loss: 95.1820
# M1 Epoch 5, Loss: 92.2312
# M1 Epoch 6, Loss: 90.4750
# M1 Epoch 7, Loss: 88.6440
# M1 Epoch 8, Loss: 87.7380
# M1 Epoch 9, Loss: 86.7371
# M1 Epoch 10, Loss: 86.0818
# M1 Epoch 11, Loss: 85.6671
# M1 Epoch 12, Loss: 85.4160
# M1 Epoch 13, Loss: 85.0672
# M1 Epoch 14, Loss: 84.8246
# M1 Epoch 15, Loss: 84.2878
# M1 Epoch 16, Loss: 83.8913
# M1 Epoch 17, Loss: 83.5609
# M1 Epoch 18, Loss: 83.0985
# M1 Epoch 19, Loss: 82.9858
# M1 Epoch 20, Loss: 82.5610
# M1 Epoch 21, Loss: 82.3135
# M1 Epoch 22, Loss: 82.0804
# M1 Epoch 23, Loss: 81.7557
# M1 Epoch 24, Loss: 81.5660
# M1 Epoch 25, Loss: 81.2481
# M1 Epoch 26, Loss: 81.1066
# M1 Epoch 27, Loss: 80.9024
# M1 Epoch 28, Loss: 80.7922
# M1 Epoch 29, Loss: 80.5229
# M1 Epoch 30, Loss: 80.2248
# M1 Epoch 31, Loss: 80.0554
# M1 Epoch 32, Loss: 79.9232
# M1 Epoch 33, Loss: 79.7869
# M1 Epoch 34, Loss: 79.5623
# M1 Epoch 35, Loss: 79.4349
# %%
# Encoder
class Encoder(nn.Module):
    def __init__(self, input_dim, num_classes, hidden_dim, latent_dim):
        super().__init__()
        self.enc_fc1 = nn.Linear(input_dim + num_classes, hidden_dim)
        self.enc_mu = nn.Linear(hidden_dim, latent_dim) #mean of latent dist
        self.enc_logvar = nn.Linear(hidden_dim, latent_dim) #log var of latent dist

    def forward(self, x, y):
        combined = torch.cat([x, y], dim=-1)
        h = F.relu(self.enc_fc1(combined))
        mu = self.enc_mu(h)
        logvar = self.enc_logvar(h)
        return mu, logvar

# Classifier
class Classifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super().__init__()
        self.layer1 = nn.Linear(input_dim, hidden_dim)
        self.layer2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        h = F.relu(self.layer1(x))
        logits = self.layer2(h)
        return logits

# Decoder
class Decoder(nn.Module):
    def __init__(self, latent_dim, num_classes, hidden_dim, output_dim):
        super().__init__()
        self.dec_fc1 = nn.Linear(latent_dim + num_classes, hidden_dim)
        self.dec_fc2 = nn.Linear(hidden_dim, output_dim)

    def forward(self, z, y):
        combined = torch.cat([z, y], dim=-1)
        h = F.relu(self.dec_fc1(combined))
        x_hat = self.dec_fc2(h)
        return x_hat

# %%
# SSL model
class SSL(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim, num_classes, learning_rate):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.latent_dim = latent_dim
        self.num_classes = num_classes
        self.learning_rate = learning_rate

        self.classifier = Classifier(input_dim, hidden_dim, num_classes)
        self.encoder = Encoder(input_dim, num_classes, hidden_dim, latent_dim)
        self.decoder = Decoder(latent_dim, num_classes, hidden_dim, input_dim)

        self.optimizer = optim.Adam(self.parameters(), lr=self.learning_rate)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    def classify(self, x):
        return self.classifier(x)

    def encode(self, x, y):
        mu, logvar = self.encoder(x, y)
        z = self.reparameterize(mu, logvar)
        return z, mu, logvar

    def decode(self, z, y):
        return self.decoder(z, y)

    def reparameterize(self, mu, logvar):
        # Reparameterization trick to sample from the latent space.
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x_l, y_l, x_u):
        """
        x_l: labeled data
        y_l: labels
        x_u: unlabeled data

        """
        # Obtain classifier scores for labeled and unlabeled data.
        scores_l = self.classifier(x_l)
        scores_u = self.classifier(x_u)
        y_u_prob = F.softmax(scores_u, dim=1)

        # Labeled part
        y_l_onehot = F.one_hot(y_l, self.num_classes).float()
        z_l, mu_l, logvar_l = self.encode(x_l, y_l_onehot)
        x_recon = self.decode(z_l, y_l_onehot)

        # Unlabeled part
        loss_u_components = []
        for i in range(self.num_classes):
            y_u = torch.full((x_u.size(0),), i, dtype=torch.long, device=x_u.device)
            y_u_onehot = F.one_hot(y_u, self.num_classes).float()
            z_u, mu_u, logvar_u = self.encode(x_u, y_u_onehot)
            x_recon_u = self.decode(z_u, y_u_onehot)

            # Compute ELBO loss for this label.
            loss_u = self.elbo_loss(x_u, x_recon_u, mu_u, logvar_u)
            loss_u_components.append(loss_u.unsqueeze(1))

        loss_u_stack = torch.cat(loss_u_components, dim=1)

        # Weight the losses by the classifier’s predicted probabilities.
        loss_u = torch.sum(y_u_prob * (loss_u_stack + torch.log(y_u_prob + 1e-8)), dim=1)

        # Total Loss
        classification_loss = F.cross_entropy(scores_l, y_l)
        labeled_loss = self.elbo_loss(x_l, x_recon, mu_l, logvar_l)
        unlabeled_loss = loss_u.mean()

        total_loss = labeled_loss.mean() + unlabeled_loss + 0.1 * classification_loss

        return total_loss, scores_u

    def elbo_loss(self, x, x_recon, mu, logvar):
        # KL divergence between latent distribution and standard normal
        kld = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp(), dim=1)
        # Reconstruction loss
        recon_loss = F.mse_loss(x_recon, x, reduction='none').sum(dim=1)
        #recon_loss = F.binary_cross_entropy_with_logits(x_recon, x, reduction='none').sum(dim=1)
        return recon_loss + kld

    def train_step(self, x_l, y_l, x_u):
        # Training loop
        self.optimizer.zero_grad()
        loss, _ = self.forward(x_l, y_l, x_u)
        loss.backward()
        #clip_grad_value_(self.parameters(), 5.0)
        self.optimizer.step()
        return loss.item()

    def predict(self, x):
        with torch.no_grad():
            scores = self.classifier(x)
        return torch.argmax(scores, dim=1)

    def visualize_latent_tsne(self, dataloader, num_samples=1000):
        self.eval()
        latents = []
        labels = []

        with torch.no_grad():
            for x, y in dataloader:
                x = x.to(self.device)
                y_onehot = F.one_hot(y, self.num_classes).float().to(self.device)

                # Get latent representation
                z, _, _ = self.encode(x, y_onehot)

                latents.append(z.cpu())
                labels.append(y.cpu())

                if sum(len(l) for l in latents) >= num_samples:
                    break

        latents = torch.cat(latents)[:num_samples].numpy()
        labels = torch.cat(labels)[:num_samples].numpy()

        # Perform T-SNE
        tsne = TSNE(n_components=2, random_state=42)
        latent_tsne = tsne.fit_transform(latents)

        # Plot
        plt.figure(figsize=(10, 8))
        scatter = plt.scatter(latent_tsne[:, 0], latent_tsne[:, 1], c=labels,
                            cmap='tab10', alpha=0.6)
        plt.colorbar(scatter, ticks=range(10))
        plt.title('T-SNE Visualization of Latent Space')
        plt.show()

    def generate_conditional_samples(self, m1_model, num_samples=10):
        """Generate samples using the full M1+M2 pipeline."""
        self.eval()
        samples = []

        with torch.no_grad():
            for c in range(self.num_classes):
                # Create class label
                y = torch.full((num_samples,), c, device=self.device)
                y_onehot = F.one_hot(y, self.num_classes).float()

                # Sample the latent variable
                z_ssl = torch.randn(num_samples, self.latent_dim, device=self.device)

                # Generate M1 latent variable
                z_m1 = self.decoder(z_ssl, y_onehot)

                # Decode to image space using M1's decoder
                x_gen = m1_model.decode(z_m1)

                samples.append(x_gen.cpu())

        # Plot grid
        fig, axs = plt.subplots(self.num_classes, num_samples,
                              figsize=(num_samples, self.num_classes))

        for row in range(self.num_classes):
            for col in range(num_samples):
                axs[row, col].imshow(samples[row][col].view(3, 32, 32).permute(1, 2, 0).cpu().numpy())
                axs[row, col].axis('off')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## Using all unlabeled dataset

# %%
labels_list = [100, 1000, 3000] # Different label size

num_classes = 10

# # Create a semi-supervised split: We make the classes balanced in the supervised labels.

for labeled_size in labels_list:
    per_class = labeled_size // num_classes

    latent_targets = train_latent_dataset.tensors[1]

    labeled_indices = []
    for c in range(num_classes):

        c_indices = (latent_targets == c).nonzero(as_tuple=True)[0]

        c_indices = c_indices[torch.randperm(len(c_indices))]

        labeled_indices.extend(c_indices[:per_class].tolist())


    all_indices = set(range(len(train_latent_dataset)))

    unlabeled_indices = list(all_indices - set(labeled_indices))

    labeled_dataset = Subset(train_latent_dataset, labeled_indices)
    unlabeled_dataset = Subset(train_latent_dataset, unlabeled_indices)

    if labeled_size == 100:
        batch_size_labeled = 1
        batch_size = 499
    elif labeled_size == 1000:
        batch_size_labeled = 10
        batch_size = 490
    elif labeled_size == 3000:
        batch_size_labeled = 30
        batch_size = 470

    labeled_loader = DataLoader(labeled_dataset, batch_size=batch_size_labeled,
                                shuffle=True, pin_memory=True)
    unlabeled_loader = DataLoader(unlabeled_dataset, batch_size=batch_size,
                                  shuffle=True, pin_memory=True)

    model = SSL(vae_latent_dim, hidden_dim, latent_dim, num_classes, learning_rate)
    model = model.to(device)
    epoch_losses = []

    # Training loop
    print(f"Starting training with {labeled_size} labels and {len(train_dataset)-labeled_size} without labels...")
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        num_batches = 0
        labeled_samples_count = 0
        unlabeled_samples_count = 0

        for (z_l, y_l), (z_u, _) in zip(labeled_loader, unlabeled_loader):

            # Update counters
            num_batches += 1
            labeled_samples_count += z_l.size(0)
            unlabeled_samples_count += z_u.size(0)

            z_l = z_l.to(device)
            y_l = y_l.to(device)
            z_u = z_u.to(device)

            loss = model.train_step(z_l, y_l, z_u)
            total_loss += loss

        avg_loss = total_loss / (len(labeled_loader)+len(unlabeled_loader))
        epoch_losses.append(avg_loss)
        print(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4f}")
    print(f"  Processed {num_batches} batches per epoch: {labeled_samples_count} labeled samples, {unlabeled_samples_count} unlabeled samples")

    # Plot training loss curve
    plt.figure()
    plt.plot(epoch_losses, marker='o')
    plt.title(f'Training Loss (Labeled Samples: {labeled_size})')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.show()

    # # Evaluate on test data.
    test_loader = DataLoader(test_latent_dataset, batch_size=batch_size, shuffle=False)

    model.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for z, y in test_loader:
            z = z.to(device)
            y = y.to(device)
            preds = model.predict(z)
            y_true.extend(y.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    # Calculate accuracy
    accuracy = np.mean(np.array(y_true) == np.array(y_pred)) * 100
    print(f"Test Accuracy ({labeled_size} labels): {accuracy:.2f}%")

    # Generate confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Confusion matrix plot
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(num_classes))

    fig, ax = plt.subplots(figsize=(8, 6))
    disp.plot(cmap='Blues', ax=ax, values_format='d')

    ax.set_title(f'Confusion Matrix (Labeled Size: {labeled_size})')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()

    print('----------------------------------------------------------------')
# Out:
# Starting training with 100 labels and 49900 without labels...
# Epoch [1/100], Average Loss: 13.3389
# Epoch [2/100], Average Loss: 12.5507
# Epoch [3/100], Average Loss: 12.2375
# Epoch [4/100], Average Loss: 12.1276
# Epoch [5/100], Average Loss: 11.9765
# Epoch [6/100], Average Loss: 11.9753
# Epoch [7/100], Average Loss: 11.7608
# Epoch [8/100], Average Loss: 11.6449
# Epoch [9/100], Average Loss: 11.5101
# Epoch [10/100], Average Loss: 11.5989
# Epoch [11/100], Average Loss: 11.5029
# Epoch [12/100], Average Loss: 11.2115
# Epoch [13/100], Average Loss: 11.3376
# Epoch [14/100], Average Loss: 11.2252
# Epoch [15/100], Average Loss: 11.2324
# Epoch [16/100], Average Loss: 11.0454
# Epoch [17/100], Average Loss: 11.1220
# Epoch [18/100], Average Loss: 11.1698
# Epoch [19/100], Average Loss: 11.0632
# Epoch [20/100], Average Loss: 10.8298
# Epoch [21/100], Average Loss: 10.9999
# Epoch [22/100], Average Loss: 10.8375
# Epoch [23/100], Average Loss: 10.9191
# Epoch [24/100], Average Loss: 10.7323
# Epoch [25/100], Average Loss: 10.9634
# Epoch [26/100], Average Loss: 10.8107
# Epoch [27/100], Average Loss: 10.7853
# Epoch [28/100], Average Loss: 10.5999
# Epoch [29/100], Average Loss: 10.7089
# Epoch [30/100], Average Loss: 10.7106
# Epoch [31/100], Average Loss: 10.8835
# Epoch [32/100], Average Loss: 10.5671
# Epoch [33/100], Average Loss: 10.6989
# Epoch [34/100], Average Loss: 10.7387
# Epoch [35/100], Average Loss: 10.7889
# Epoch [36/100], Average Loss: 10.7034
# Epoch [37/100], Average Loss: 10.6440
# Epoch [38/100], Average Loss: 10.8841
# Epoch [39/100], Average Loss: 10.5490
# Epoch [40/100], Average Loss: 10.5186
# Epoch [41/100], Average Loss: 10.6633
# Epoch [42/100], Average Loss: 10.3468
# Epoch [43/100], Average Loss: 10.6910
# Epoch [44/100], Average Loss: 10.5465
# Epoch [45/100], Average Loss: 10.6725
# Epoch [46/100], Average Loss: 10.4014
# Epoch [47/100], Average Loss: 10.8204
# Epoch [48/100], Average Loss: 10.5714
# Epoch [49/100], Average Loss: 10.5761
# Epoch [50/100], Average Loss: 10.2965
# Epoch [51/100], Average Loss: 10.3557
# Epoch [52/100], Average Loss: 10.6068
# Epoch [53/100], Average Loss: 10.3670
# Epoch [54/100], Average Loss: 10.4338
# Epoch [55/100], Average Loss: 10.2295
# Epoch [56/100], Average Loss: 10.1004
# Epoch [57/100], Average Loss: 10.3040
# Epoch [58/100], Average Loss: 10.2596
# Epoch [59/100], Average Loss: 10.3597
# Epoch [60/100], Average Loss: 9.9484
# Epoch [61/100], Average Loss: 10.1909
# Epoch [62/100], Average Loss: 10.1279
# Epoch [63/100], Average Loss: 10.1552
# Epoch [64/100], Average Loss: 10.3447
# Epoch [65/100], Average Loss: 10.2254
# Epoch [66/100], Average Loss: 10.4882
# Epoch [67/100], Average Loss: 10.1203
# Epoch [68/100], Average Loss: 10.1320
# Epoch [69/100], Average Loss: 10.3107
# Epoch [70/100], Average Loss: 9.9609
# Epoch [71/100], Average Loss: 10.2401
# Epoch [72/100], Average Loss: 10.1717
# Epoch [73/100], Average Loss: 10.2414
# Epoch [74/100], Average Loss: 10.2295
# Epoch [75/100], Average Loss: 10.0498
# Epoch [76/100], Average Loss: 10.3704
# Epoch [77/100], Average Loss: 10.1098
# Epoch [78/100], Average Loss: 10.0680
# Epoch [79/100], Average Loss: 9.8575
# Epoch [80/100], Average Loss: 10.0248
# Epoch [81/100], Average Loss: 10.0563
# Epoch [82/100], Average Loss: 10.2422
# Epoch [83/100], Average Loss: 10.3335
# Epoch [84/100], Average Loss: 9.9798
# Epoch [85/100], Average Loss: 10.3327
# Epoch [86/100], Average Loss: 9.9638
# Epoch [87/100], Average Loss: 9.9949
# Epoch [88/100], Average Loss: 10.0582
# Epoch [89/100], Average Loss: 10.1208
# Epoch [90/100], Average Loss: 9.9994
# Epoch [91/100], Average Loss: 9.9664
# Epoch [92/100], Average Loss: 9.9858
# Epoch [93/100], Average Loss: 10.0979
# Epoch [94/100], Average Loss: 9.9711
# Epoch [95/100], Average Loss: 9.9193
# Epoch [96/100], Average Loss: 9.8297
# Epoch [97/100], Average Loss: 9.8401
# Epoch [98/100], Average Loss: 9.7783
# Epoch [99/100], Average Loss: 10.0245
# Epoch [100/100], Average Loss: 10.0179
#   Processed 100 batches per epoch: 100 labeled samples, 49900 unlabeled samples
# Test Accuracy (100 labels): 25.98%
# ----------------------------------------------------------------
# Starting training with 1000 labels and 49000 without labels...
# Epoch [1/100], Average Loss: 12.9560
# Epoch [73/100], Average Loss: 10.3249
# Epoch [74/100], Average Loss: 10.4429
# Epoch [75/100], Average Loss: 10.3840
# Epoch [76/100], Average Loss: 10.4374
# Epoch [77/100], Average Loss: 10.4023
# Epoch [78/100], Average Loss: 10.3927
# Epoch [79/100], Average Loss: 10.3915
# Epoch [80/100], Average Loss: 10.4464
# Epoch [81/100], Average Loss: 10.2817
# Epoch [82/100], Average Loss: 10.3923
# Epoch [83/100], Average Loss: 10.4212
# Epoch [84/100], Average Loss: 10.3567
# Epoch [85/100], Average Loss: 10.3664
# Epoch [86/100], Average Loss: 10.4368
# Epoch [87/100], Average Loss: 10.4024
# Epoch [88/100], Average Loss: 10.3820
# Epoch [89/100], Average Loss: 10.3698
# Epoch [90/100], Average Loss: 10.2834
# Epoch [91/100], Average Loss: 10.3657
# Epoch [92/100], Average Loss: 10.3434
# Epoch [93/100], Average Loss: 10.3284
# Epoch [94/100], Average Loss: 10.4100
# Epoch [95/100], Average Loss: 10.3269
# Epoch [96/100], Average Loss: 10.3449
# Epoch [97/100], Average Loss: 10.3645
# Epoch [98/100], Average Loss: 10.3424
# Epoch [99/100], Average Loss: 10.2699
# Epoch [100/100], Average Loss: 10.3517
#   Processed 100 batches per epoch: 1000 labeled samples, 49000 unlabeled samples
# Test Accuracy (1000 labels): 35.05%
# ----------------------------------------------------------------
# Starting training with 3000 labels and 47000 without labels...
# Epoch [1/100], Average Loss: 12.7222
# Epoch [2/100], Average Loss: 11.8915
# Epoch [3/100], Average Loss: 11.5440
# Epoch [4/100], Average Loss: 11.3852
# Epoch [5/100], Average Loss: 11.3155
# Epoch [6/100], Average Loss: 11.2211
# Epoch [7/100], Average Loss: 11.1556
# Epoch [8/100], Average Loss: 11.1104
# Epoch [9/100], Average Loss: 11.1052
# Epoch [10/100], Average Loss: 11.0563
# Epoch [11/100], Average Loss: 11.0462
# Epoch [12/100], Average Loss: 10.9500
# Epoch [13/100], Average Loss: 10.9430
# Epoch [14/100], Average Loss: 10.9435
# Epoch [15/100], Average Loss: 10.8958
# Epoch [16/100], Average Loss: 10.8767
# Epoch [17/100], Average Loss: 10.8217
# Epoch [18/100], Average Loss: 10.7828
# Epoch [19/100], Average Loss: 10.7817
# Epoch [20/100], Average Loss: 10.7778
# Epoch [21/100], Average Loss: 10.6765
# Epoch [22/100], Average Loss: 10.6691
# Epoch [23/100], Average Loss: 10.6856
# Epoch [24/100], Average Loss: 10.6696
# Epoch [25/100], Average Loss: 10.6371
# Epoch [26/100], Average Loss: 10.6116
# Epoch [27/100], Average Loss: 10.6411
# Epoch [28/100], Average Loss: 10.5511
# Epoch [29/100], Average Loss: 10.5940
# Epoch [30/100], Average Loss: 10.5455
# Epoch [31/100], Average Loss: 10.5576
# Epoch [32/100], Average Loss: 10.5038
# Epoch [33/100], Average Loss: 10.4942
# Epoch [34/100], Average Loss: 10.4798
# Epoch [35/100], Average Loss: 10.4768
# Epoch [36/100], Average Loss: 10.4375
# Epoch [37/100], Average Loss: 10.4780
# Epoch [38/100], Average Loss: 10.4683
# Epoch [39/100], Average Loss: 10.4654
# Epoch [40/100], Average Loss: 10.4506
# Epoch [41/100], Average Loss: 10.4484
# Epoch [42/100], Average Loss: 10.4068
# Epoch [43/100], Average Loss: 10.4103
# Epoch [44/100], Average Loss: 10.4235
# Epoch [45/100], Average Loss: 10.3948
# Epoch [46/100], Average Loss: 10.4239
# Epoch [47/100], Average Loss: 10.3997
# Epoch [48/100], Average Loss: 10.4084
# Epoch [49/100], Average Loss: 10.3526
# Epoch [50/100], Average Loss: 10.3920
# Epoch [51/100], Average Loss: 10.3790
# Epoch [52/100], Average Loss: 10.3468
# Epoch [53/100], Average Loss: 10.3549
# Epoch [54/100], Average Loss: 10.3438
# Epoch [55/100], Average Loss: 10.3558
# Epoch [56/100], Average Loss: 10.3775
# Epoch [57/100], Average Loss: 10.3662
# Epoch [58/100], Average Loss: 10.3683
# Epoch [59/100], Average Loss: 10.3911
# Epoch [60/100], Average Loss: 10.3249
# Epoch [61/100], Average Loss: 10.3133
# Epoch [62/100], Average Loss: 10.3692
# Epoch [63/100], Average Loss: 10.3403
# Epoch [64/100], Average Loss: 10.3571
# Epoch [65/100], Average Loss: 10.3082
# Epoch [66/100], Average Loss: 10.3600
# Epoch [67/100], Average Loss: 10.2874
# Epoch [68/100], Average Loss: 10.2848
# Epoch [69/100], Average Loss: 10.3070
# Epoch [70/100], Average Loss: 10.2967
# Epoch [71/100], Average Loss: 10.2946
# Epoch [72/100], Average Loss: 10.2750
# Epoch [73/100], Average Loss: 10.3060
# Epoch [74/100], Average Loss: 10.2893
# Epoch [75/100], Average Loss: 10.2969
# Epoch [76/100], Average Loss: 10.2950
# Epoch [77/100], Average Loss: 10.3148
# Epoch [78/100], Average Loss: 10.3036
# Epoch [79/100], Average Loss: 10.2428
# Epoch [80/100], Average Loss: 10.2808
# Epoch [81/100], Average Loss: 10.2432
# Epoch [82/100], Average Loss: 10.2992
# Epoch [83/100], Average Loss: 10.2957
# Epoch [84/100], Average Loss: 10.2448
# Epoch [85/100], Average Loss: 10.3086
# Epoch [86/100], Average Loss: 10.2787
# Epoch [87/100], Average Loss: 10.2628
# Epoch [88/100], Average Loss: 10.2247
# Epoch [89/100], Average Loss: 10.2617
# Epoch [90/100], Average Loss: 10.2466
# Epoch [91/100], Average Loss: 10.2443
# Epoch [92/100], Average Loss: 10.2716
# Epoch [93/100], Average Loss: 10.2879
# Epoch [94/100], Average Loss: 10.2462
# Epoch [95/100], Average Loss: 10.2232
# Epoch [96/100], Average Loss: 10.2321
# Epoch [97/100], Average Loss: 10.2559
# Epoch [98/100], Average Loss: 10.2685
# Epoch [99/100], Average Loss: 10.2338
# Epoch [100/100], Average Loss: 10.2156
#   Processed 100 batches per epoch: 3000 labeled samples, 47000 unlabeled samples
# Test Accuracy (3000 labels): 37.77%
# ----------------------------------------------------------------

# %%
print("Generating latent space visualization...")
model.visualize_latent_tsne(test_loader)
# Out:
# Generating latent space visualization...

# %%
print("Generating conditional samples...")
model.generate_conditional_samples(m1_model=m1, num_samples=10)
# Out:
# Generating conditional samples...
